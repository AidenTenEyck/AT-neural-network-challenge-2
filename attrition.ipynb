# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
\

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y = attrition_df[["Attrition", 'Department']]
y_df = pd.DataFrame(y)
y_df
# Out:
#      Attrition              Department
# 0          Yes                   Sales
# 1           No  Research & Development
# 2          Yes  Research & Development
# 3           No  Research & Development
# 4           No  Research & Development
# ...        ...                     ...
# 1465        No  Research & Development
# 1466        No  Research & Development
# 1467        No  Research & Development
# 1468        No                   Sales
# 1469        No  Research & Development
#
# [1470 rows x 2 columns]

# %%
# Create a list of at least 10 column names to use as X data
X=attrition_df[['Age', 'Education','HourlyRate','EnvironmentSatisfaction','JobSatisfaction',
                'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsInCurrentRole']]


# Create X_df using your selected columns
X_df=pd.DataFrame(x)


# Show the data types for X_df
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Education                1470 non-null   int64
#  2   HourlyRate               1470 non-null   int64
#  3   EnvironmentSatisfaction  1470 non-null   int64
#  4   JobSatisfaction          1470 non-null   int64
#  5   PercentSalaryHike        1470 non-null   int64
#  6   TotalWorkingYears        1470 non-null   int64
#  7   TrainingTimesLastYear    1470 non-null   int64
#  8   YearsAtCompany           1470 non-null   int64
#  9   YearsInCurrentRole       1470 non-null   int64
# dtypes: int64(10)
# memory usage: 115.0 KB

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
y_att=pd.DataFrame(y_df['Attrition'])
y_dep=pd.DataFrame(y_df['Department'])

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_att_train, y_att_test, y_dep_train, y_dep_test = train_test_split(X, y_att, y_dep, random_state=1)

# %%
# Create a StandardScaler
scaler=StandardScaler()

# Fit the StandardScaler to the training data
scaler.fit(X_train)
scaler.fit(X_test)

# Scale the training and testing data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder
encode = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
y_dep_encoded_train = encode.fit_transform(y_dep_train)
y_dep_encoded_test = encode.transform(y_dep_test)

# Create two new variables by applying the encoder
# to the training and testing data
y_dep_encoded_train_df = pd.DataFrame(y_dep_encoded_train)
y_dep_encoded_test_df = pd.DataFrame(y_dep_encoded_test)

# %%
# Create a OneHotEncoder for the Attrition column
encode = OneHotEncoder(sparse_output=False)

# Fit the encoder to the training data
y_att_encoded_train = encode.fit_transform(y_att_train)
y_att_encoded_test = encode.transform(y_att_test)
# Create two new variables by applying the encoder
# to the training and testing data
y_att_encoded_train_df = pd.DataFrame(y_att_encoded_train)
y_att_encoded_test_df = pd.DataFrame(y_att_encoded_test)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
#model = keras.Model(inputs=input_layer, outputs=[dep_output, att_output])
encoder_dep = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
y_dep_encoded = encoder_dep.fit_transform(y_dep.values.reshape(-1, 1))
encoder_att = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
y_att_encoded = encoder_att.fit_transform(y_att.values.reshape(-1, 1))

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
#model.fit(X, {'dep_output': y_dep_encoded, 'att_output': y_att_encoded}, epochs=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-16063e7528b0> in <cell line: 1>()
# ----> 1 model.fit(X, {'dep_output': y_dep_encoded, 'att_output': y_att_encoded}, epochs=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/trainer.py in _pythonify_logs(self, logs)
#     929     def _pythonify_logs(self, logs):
#     930         result = {}
# --> 931         for key, value in sorted(logs.items()):
#     932             if isinstance(value, dict):
# ...

# %%
# Find the number of columns in the X training data
num_columns = X_train.shape[1]
# Create the input layer
input_layer = layers.Input(shape=(X.shape[1],), name='input_features')
# Create at least two shared layers
shared_1 = layers.Dense(64, activation='relu')(input_layer)
shared_2 = layers.Dense(32, activation='relu')(shared_1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer
dep_layer = layers.Dense(16, activation='relu')(shared_2)
# Create the hidden layer
dep_hidden=layers.Dense(8, activation='relu')(dep_layer)

# Create the output layer
dep_output=layers.Dense(2, activation='softmax', name='dep_output')(dep_hidden)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer
att_layer = layers.Dense(16, activation='relu')(shared_2)
# Create the hidden layer
att_hidden=layers.Dense(8, activation='relu')(att_layer)

# Create the output layer
att_output=layers.Dense(3, activation='softmax', name='att_output')(att_hidden)

# %%
# Create the model
model = Model(inputs=input_layer, outputs=[dep_output, att_output])

# Compile the model
model.compile(optimizer='adam',
              loss={'dep_output': 'categorical_crossentropy', 'att_output': 'categorical_crossentropy'},
              metrics={'dep_output': 'accuracy', 'att_output': 'accuracy'})

# Summarize the model
model.summary()
# Out:
# Model: "functional_25"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_features            │ (None, 10)             │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_60 (Dense)          │ (None, 64)             │            704 │ input_features[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_61 (Dense)          │ (None, 32)             │          2,080 │ dense_60[0][0]         │
# ...

# %%
# Train the model
model.fit(
    X,
    {'dep_output': y_dep_encoded, 'att_output': y_att_encoded},
    epochs=100
)
# Out:
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - att_output_accuracy: 0.3339 - att_output_loss: 4.9451 - dep_output_accuracy: 0.1893 - dep_output_loss: 0.8679 - loss: 5.8131
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - att_output_accuracy: 0.0997 - att_output_loss: 0.9495 - dep_output_accuracy: 0.0478 - dep_output_loss: 0.4857 - loss: 1.4352
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - att_output_accuracy: 0.1483 - att_output_loss: 0.8072 - dep_output_accuracy: 0.0447 - dep_output_loss: 0.4185 - loss: 1.2257
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - att_output_accuracy: 0.1397 - att_output_loss: 0.7974 - dep_output_accuracy: 0.0422 - dep_output_loss: 0.4085 - loss: 1.2059
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - att_output_accuracy: 0.1185 - att_output_loss: 0.8485 - dep_output_accuracy: 0.0517 - dep_output_loss: 0.4500 - loss: 1.2985
# Epoch 6/100
# ...

# %%
# Evaluate the model with the testing data
loss, dep_loss, att_loss, dep_accuracy, att_accuracy = model.evaluate(
    X_test_scaled,
    {'dep_output': y_dep_encoded_test, 'att_output': y_att_encoded_test},
    verbose=2)

# Print the results
print(f"Total Loss: {loss}")
print(f"Department Loss: {dep_loss}")
print(f"Attrition Loss: {att_loss}")
print(f"Department Accuracy: {dep_accuracy}")
print(f"Attrition Accuracy: {att_accuracy}")
# Out:
# 12/12 - 0s - 30ms/step - att_output_accuracy: 0.1549 - att_output_loss: 0.9235 - dep_output_accuracy: 0.6223 - dep_output_loss: 0.8572 - loss: 1.7833
# Total Loss: 1.783313274383545
# Department Loss: 0.8572322726249695
# Attrition Loss: 0.9234965443611145
# Department Accuracy: 0.15489129722118378
# Attrition Accuracy: 0.6222826242446899

# %%
# Print the accuracy for both department and attrition
print(f"Department Accuracy: {dep_accuracy}")
print(f"Attrition Accuracy: {att_accuracy}")
# Out:
# Department Accuracy: 0.15489129722118378
# Attrition Accuracy: 0.6222826242446899

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. No the goal is to figure out if employees are well suited for their departments or whether they would do better in a different one. Accuracy score is only predicting whether they're likely to leave.
# 2. SoftMax - only one I could get to work.
# 3. The accuracy of the model is low and could be improved with further tweaking.
